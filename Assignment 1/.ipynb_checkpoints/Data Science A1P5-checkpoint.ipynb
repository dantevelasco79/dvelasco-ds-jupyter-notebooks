# %%
import pandas

df = pandas.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
means = []
variances = []

columns = df.columns.tolist()
columns.remove('id')
columns.remove('date')
columns.remove('zipcode')
columns
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
for column in columns:
    means.append(df[column].mean())
    variances.append(df[column].var())
    print('feature: ' + str(column))
    print('mean: ' + str(df[column].mean()))
    print('min: ' + str(df[column].min()))
    print('max: ' + str(df[column].max()))
    print('variance: ' + str(df[column].var()) + '\n')
# Out:
# feature: price
# mean: 540088.1417665294
# min: 75000.0
# max: 7700000.0
# variance: 134782378397.24681
#
# feature: bedrooms
# mean: 3.37084162309721
# min: 0
# max: 33
# variance: 0.8650150097573724
#
# feature: bathrooms
# mean: 2.1147573219821405
# min: 0.0
# max: 8.0
# variance: 0.5931512887355798
#
# feature: sqft_living
# mean: 2079.8997362698374
# min: 290
# max: 13540
# variance: 843533.6813681519
#
# feature: sqft_lot
# mean: 15106.967565816869
# min: 520
# max: 1651359
# variance: 1715658774.1754541
#
# feature: floors
# mean: 1.4943089807060566
# min: 1.0
# max: 3.5
# variance: 0.29158800687709074
#
# feature: waterfront
# mean: 0.007541757275713691
# min: 0
# max: 1
# variance: 0.007485225502689098
#
# feature: view
# mean: 0.23430342849211122
# min: 0
# max: 4
# variance: 0.5872426169774596
#
# feature: condition
# mean: 3.4094295100171195
# min: 1
# max: 5
# variance: 0.42346651239404876
#
# feature: grade
# mean: 7.656873178179799
# min: 1
# max: 13
# ...

# %%
print('The feature with the lowest average is longitude with a mean of ' + str(min(means)))
print('The feature with the greatest average is price with a mean of ' + str(max(means)))
print('The feature with the lowest variance is waterfront with a mean of ' + str(min(variances)))
print('The feature with the greatest variance is price with a mean of ' + str(max(variances)))
# Out:
# The feature with the lowest average is longitude with a mean of -122.21389640494083
# The feature with the greatest average is price with a mean of 540088.1417665294
# The feature with the lowest variance is waterfront with a mean of 0.007485225502689098
# The feature with the greatest variance is price with a mean of 134782378397.24681

# %%
dict = {'name': [], 'corr': []}
for column in columns:
    dict['name'].append(column)
    dict['corr'].append(df[column].corr(df['price']))
corr_df = pandas.DataFrame(dict)
corr_df
# Out:
#              name      corr
# 0           price  1.000000
# 1        bedrooms  0.308350
# 2       bathrooms  0.525138
# 3     sqft_living  0.702035
# 4        sqft_lot  0.089661
# 5          floors  0.256794
# 6      waterfront  0.266369
# 7            view  0.397293
# 8       condition  0.036362
# 9           grade  0.667434
# 10     sqft_above  0.605567
# 11  sqft_basement  0.323816
# 12       yr_built  0.054012
# 13   yr_renovated  0.126434
# 14            lat  0.307003
# 15           long  0.021626
# 16  sqft_living15  0.585379
# 17     sqft_lot15  0.082447

# %% [markdown]
# Every feature is positiively correlated to the response. The feature with the greatest correlation to price besides itself is sqft_living. I was unable to find a negative correlation coefficient with response.
